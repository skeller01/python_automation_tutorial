# %% [markdown]
# ## Automate with Python - Full Course for Beginners
# https://www.youtube.com/watch?v=PXMJ6FS7llk
#
# https://stackoverflow.com/questions/59309575/urlopen-error-ssl-certificate-verify-failed-certificate-verify-failed-unabl

# %%
#packages 
import pandas as pd 
import ssl

#create ssl context - see link in the main window 
ssl._create_default_https_context = ssl._create_unverified_context

# %%
#extract tables from websites 
immigration = pd.read_html('https://en.wikipedia.org/wiki/Illegal_immigration_to_the_United_States')

# %%
len(immigration)
# Out:
# 16

# %%
immigration[2]
# Out:
#    State of residence  Estimated population in January  Percent of total
# 0          All states                         12120000               100
# 1          California                          2900000                24
# 2               Texas                          1920000                16
# 3             Florida                           760000                 6
# 4            New York                           640000                 5
# 5            Illinois                           550000                 5
# 6          New Jersey                           480000                 4
# 7             Georgia                           430000                 4
# 8      North Carolina                           400000                 3
# 9             Arizona                           370000                 3
# 10         Washington                           290000                 2
# 11       Other states                          3370000                28

# %% [markdown]
# Grab a file from CSV on the web

# %%
#read one file 
df_premier22 = pd.read_csv('https://www.football-data.co.uk/mmz4281/2223/E0.csv')

# %%
#showing dataframe 
df_premier22.head()
# Out:
#   Div        Date   Time        HomeTeam       AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0  E0  05/08/2022  20:00  Crystal Palace        Arsenal     0     2   A     0
# 1  E0  06/08/2022  12:30          Fulham      Liverpool     2     2   D     1
# 2  E0  06/08/2022  15:00     Bournemouth    Aston Villa     2     0   H     1
# 3  E0  06/08/2022  15:00           Leeds         Wolves     2     1   H     1
# 4  E0  06/08/2022  15:00       Newcastle  Nott'm Forest     2     0   H     0
#
#    HTAG  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  \
# 0     1  ...     1.76  0.50      2.09      1.84   2.04   1.88     2.09
# 1     0  ...     2.73  1.75      1.90      2.03   1.91   2.02     2.01
# 2     0  ...     1.76  0.50      1.93      2.00   1.93   2.00     1.94
# 3     1  ...     1.87 -0.25      2.08      1.85   2.10   1.84     2.14
# 4     0  ...     1.89 -1.00      1.97      1.96   1.99   1.93     2.19
#
#    MaxCAHA  AvgCAHH  AvgCAHA
# 0     1.88     2.03     1.85
# ...

# %%
#rename columns 
df_premier22.rename(columns ={'FTHG':'Home_Goals','FTAG':'Nonsense'}, inplace=True)
df_premier22.head()
# Out:
#   Div        Date   Time        HomeTeam       AwayTeam  Home_Goals  Nonsense  \
# 0  E0  05/08/2022  20:00  Crystal Palace        Arsenal           0         2
# 1  E0  06/08/2022  12:30          Fulham      Liverpool           2         2
# 2  E0  06/08/2022  15:00     Bournemouth    Aston Villa           2         0
# 3  E0  06/08/2022  15:00           Leeds         Wolves           2         1
# 4  E0  06/08/2022  15:00       Newcastle  Nott'm Forest           2         0
#
#   FTR  HTHG  HTAG  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  \
# 0   A     0     1  ...     1.76  0.50      2.09      1.84   2.04   1.88
# 1   D     1     0  ...     2.73  1.75      1.90      2.03   1.91   2.02
# 2   H     1     0  ...     1.76  0.50      1.93      2.00   1.93   2.00
# 3   H     1     1  ...     1.87 -0.25      2.08      1.85   2.10   1.84
# 4   H     0     0  ...     1.89 -1.00      1.97      1.96   1.99   1.93
#
#    MaxCAHH  MaxCAHA  AvgCAHH  AvgCAHA
# ...

# %% [markdown]
# read a pdf table
